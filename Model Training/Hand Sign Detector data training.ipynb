# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.7/510.7 KB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 23.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %% [markdown]
# # Training the model

# %%
# !yolo task=detect mode=train model=yolov8l.pt data='/content/drive/MyDrive/Object Detection Datasets/Hand_Sign_detector_dataset/data.yaml' epochs=10 imgsz=640
# Out:
# Ultralytics YOLOv8.0.71 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
